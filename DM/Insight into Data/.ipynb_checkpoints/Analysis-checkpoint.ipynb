# %%
import pandas as pd
import re
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed',)).History will not be written to the database.

# %%
data = pd.read_excel('Online Retail.xlsx')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
for x in list(set(data['InvoiceNo'].values)):
    try:
        int(x)
    except:
        print(x)
# Out:
# C555892
# C565284
# C557658
# C538690
# C537024
# C538691
# C546897
# C546867
# C572441
# C538847
# C562876
# C578257
# C545720
# C572027
# C556793
# C538463
# C564908
# C573949
# C549666
# C566945
# C554873
# C540360
# C574337
# C574026
# C554532
# C560564
# C559568
# C555595
# C572916
# C556532
# C544099
# C546773
# C553518
# C554136
# C541710
# C569553
# C578377
# C578280
# C566751
# C561469
# C572473
# C559744
# C561591
# C547854
# C568348
# C536757
# C554006
# C538806
# C547368
# C570464
# C571325
# C574900
# C559681
# C542082
# C577399
# C562594
# C579277
# C558037
# C543195
# C571859
# C570483
# C567712
# C565683
# C579748
# C576919
# C553560
# C552709
# C551948
# C578932
# C579894
# C566753
# C579192
# C541433
# C580711
# C537857
# C538734
# C560608
# C566470
# C579970
# C554983
# C564138
# C559175
# C559189
# C539258
# C546267
# C539983
# C567440
# C563107
# C542951
# C575223
# C536854
# C547904
# C560436
# C550809
# C564845
# C569949
# C579907
# C550009
# C539726
# C549685
# ...

# %%
for x in list(set(data['StockCode'].values)):
    print(x)
# Out:
# 90112
# 90114
# 90115
# 90116
# 90027A
# 90211B
# 84898F
# 90118
# 90119
# 90131
# 90132
# 90133
# 90134
# 90135
# 90136
# 90137
# 90138
# 35815P
# 90140
# 90143
# 90144
# 90145
# 90146
# 90147
# 85136A
# 90148
# 90149
# 90151
# 85184c
# 90063B
# 90154
# 90155
# 90156
# 90157
# 90158
# 35823P
# 90159
# 90166
# 90167
# 90168
# 90169
# 90170
# 90201A
# 90173
# 90174
# 90024D
# 22808
# 90214O
# 90188
# 90191
# 90192
# 90194
# 51020B
# 90204
# 84931B
# 90208
# 37471
# 84424A
# 84927D
# 84804A
# 84509g
# 84800S
# 47503A
# 22823
# 85061W
# 90182A
# 22826
# 90177B
# 90129D
# 82613a
# 84661C
# 82095
# 48173c
# 72802A
# 22833
# 85049c
# 37444A
# 84968F
# 47559b
# DCGS0076
# 85019C
# 90129C
# 90036F
# 90198A
# 85031B
# 90013D
# 37503
# 90042A
# 46000R
# 17012E
# 90130A
# 85114C
# 84251F
# 90124B
# 90036B
# 90125A
# 90120B
# 90082B
# 90195B
# 85206A
# 72807C
# 72807c
# 37489A
# 85032B
# 72351A
# 35909A
# 22871
# 72807b
# 79062D
# 17091J
# 84247K
# 84795B
# 84201C
# 47344B
# DCGS0068
# 85099C
# ...

# %%
for x in list(data[['InvoiceNo', 'Quantity']].values):
    if x[1] <= 0:
        print(x)
# Out:
# ['C536379' -1]
# ['C536383' -1]
# ['C536391' -12]
# ['C536391' -24]
# ['C536391' -24]
# ['C536391' -24]
# ['C536391' -12]
# ['C536391' -12]
# ['C536391' -24]
# ['C536506' -6]
# ['C536543' -1]
# ['C536543' -2]
# ['C536548' -4]
# ['C536548' -5]
# ['C536548' -1]
# ['C536548' -7]
# ['C536548' -1]
# ['C536548' -2]
# ['C536548' -1]
# ['C536548' -2]
# ['C536548' -6]
# ['C536548' -1]
# ['C536548' -2]
# ['C536548' -3]
# ['C536548' -1]
# ['C536548' -4]
# [536589 -10]
# ['C536606' -2]
# ['C536622' -2]
# ['C536625' -2]
# ['C536642' -1]
# ['C536734' -4]
# ['C536734' -1]
# ['C536737' -2]
# ['C536757' -9360]
# ['C536758' -1]
# ['C536760' -1]
# ['C536760' -3]
# [536764 -38]
# ['C536807' -2]
# ['C536807' -1]
# ['C536812' -36]
# ['C536812' -192]
# ['C536812' -144]
# ['C536812' -144]
# ['C536812' -192]
# ['C536812' -144]
# ['C536814' -2]
# ['C536814' -6]
# ['C536814' -2]
# ['C536814' -12]
# ['C536814' -1]
# ['C536815' -1]
# ['C536815' -1]
# ['C536816' -2]
# ['C536817' -1]
# ['C536817' -1]
# ...

# %%
from datetime import datetime, timedelta
list(set(data['InvoiceDate'].values))
for x in data['InvoiceDate']:
    if x < datetime(2010,12,1) or x > datetime(2011,12,9)+timedelta(days=1):
        print(x)
# datetime(2011,12,9)

# %%
len(set(data['CustomerID'].values))
